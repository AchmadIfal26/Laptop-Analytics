# %%
import pandas as pd # -> Module yang digunaakn untuk analisis data, editing dataframe
import numpy as np # -> Module yang digunakan untuk operasi matematika
import matplotlib.pyplot as plt # -> Module yang digunakan untuk melakukan visualisasi data
import seaborn as sns # -> Module yang digunakan untuk melakukan visualisasi data
import os # -> Untuk melakukan operasi sistem di google colab
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd # -> Module yang digunaakn untuk analisis data, editing dataframe
#       2 import numpy as np # -> Module yang digunakan untuk operasi matematika
#       3 import matplotlib.pyplot as plt # -> Module yang digunakan untuk melakukan visualisasi data
#
# ModuleNotFoundError: No module named 'pandas'

# %%
laptop = pd.read_csv("/content/Laptops.csv")
laptop
# Out:
#      Unnamed: 0    Brand               Model Name          Processor  \
# 0             0       HP             15s-fq5007TU            Core i3
# 1             1       HP             15s-fy5003TU            Core i3
# 2             2    Apple         2020 Macbook Air                 M1
# 3             3    Apple         2020 Macbook Air                 M1
# 4             4    Apple         2020 Macbook Air                 M1
# ..          ...      ...                      ...                ...
# 832         832       HP                   255 G8  Ryzen 5 Hexa Core
# 833         833     DELL            Inspiron 7430            Core i3
# 834         834      MSI  Katana 17 B13UCXK-256IN            Core i7
# 835         835  Infinix                     XL25            Core i5
# 836         836       HP              13-BE0030AU  Ryzen 5 Hexa Core
#
#     Operating System Storage    RAM           Screen Size Touch_Screen  \
# 0    Windows 11 Home  512 GB   8 GB  39.62 cm (15.6 Inch)           No
# 1    Windows 11 Home  512 GB   8 GB  39.62 cm (15.6 Inch)           No
# 2     Mac OS Big Sur  256 GB   8 GB  33.78 cm (13.3 inch)           No
# 3     Mac OS Big Sur  256 GB   8 GB  33.78 cm (13.3 inch)           No
# 4     Mac OS Big Sur  256 GB   8 GB  33.78 cm (13.3 inch)           No
# ..               ...     ...    ...                   ...          ...
# 832  Windows 11 Home  512 GB   8 GB  39.62 cm (15.6 inch)           No
# 833  Windows 11 Home    1 TB   8 GB    35.56 cm (14 inch)          Yes
# 834  Windows 11 Home    4 TB  16 GB  43.94 cm (17.3 Inch)           No
# 835  Windows 11 Home  512 GB   8 GB  39.62 cm (15.6 Inch)           No
# 836  Windows 10 Home  512 GB  16 GB  33.78 cm (13.3 inch)           No
#
#        Price
# 0    ₹38,990
# 1    ₹37,990
# 2    ₹70,990
# 3    ₹70,990
# 4    ₹70,990
# ..       ...
# 832  ₹42,990
# 833  ₹60,490
# 834  ₹88,990
# 835  ₹37,990
# 836  ₹70,500
#
# [837 rows x 10 columns]

# %%
laptop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 837 entries, 0 to 836
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        837 non-null    int64
#  1   Brand             837 non-null    object
#  2   Model Name        837 non-null    object
#  3   Processor         837 non-null    object
#  4   Operating System  837 non-null    object
#  5   Storage           825 non-null    object
#  6   RAM               837 non-null    object
#  7   Screen Size       837 non-null    object
#  8   Touch_Screen      837 non-null    object
#  9   Price             837 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 65.5+ KB

# %%
laptop.sample(10)
# Out:
#      Unnamed: 0    Brand                                         Model Name  \
# 562         562       HP                                        14-EC1019AU
# 115         115   Lenovo                                            15ITL05
# 771         771     DELL                                      Inspiron 3521
# 621         621     ASUS                                     FA577NU-LP082W
# 482         482      MSI  Summit E16 Flip A13VET-068IN NVIDIA GeForce RT...
# 236         236  Infinix                                               XL30
# 568         568     ASUS                                   K3405VCB-KM541WS
# 33           33       HP                                        14-dv2153TU
# 323         323      MSI                               Thin GF63 12VE-664IN
# 681         681     ASUS                                   UX3402VA-KM742WS
#
#              Processor Operating System Storage    RAM           Screen Size  \
# 562  Ryzen 5 Hexa Core  Windows 11 Home  512 GB  16 GB    35.56 cm (14 inch)
# 115            Core i3  Windows 11 Home     NaN   8 GB  39.62 cm (15.6 Inch)
# 771     Pentium Silver  Windows 11 Home  256 GB   8 GB  39.62 cm (15.6 Inch)
# 621  Ryzen 7 Octa Core  Windows 11 Home  512 GB  16 GB  39.62 cm (15.6 Inch)
# 482            Core i7  Windows 11 Home    1 TB  32 GB    40.64 cm (16 Inch)
# 236  Celeron Quad Core  Windows 11 Home  128 GB   4 GB  39.62 cm (15.6 Inch)
# 568  Ryzen 7 Octa Core  Windows 11 Home  512 GB  16 GB  39.62 cm (15.6 Inch)
# 33             Core i5  Windows 11 Home    1 TB  16 GB    35.56 cm (14 inch)
# 323            Core i7  Windows 11 Home    2 TB  16 GB  39.62 cm (15.6 Inch)
# 681            Core i7  Windows 11 Home  512 GB  16 GB    35.56 cm (14 Inch)
#
#     Touch_Screen      Price
# 562           No    ₹54,990
# 115           No    ₹32,990
# 771           No    ₹32,990
# 621           No    ₹94,990
# 482          Yes  ₹1,59,990
# 236           No    ₹20,990
# 568           No    ₹64,990
# 33            No    ₹66,999
# 323           No    ₹90,990
# 681           No    ₹97,990

# %%
laptop_data = laptop.set_index("Brand")

# %%
laptop_data
# Out:
#          Unnamed: 0               Model Name          Processor  \
# Brand
# HP                0             15s-fq5007TU            Core i3
# HP                1             15s-fy5003TU            Core i3
# Apple             2         2020 Macbook Air                 M1
# Apple             3         2020 Macbook Air                 M1
# Apple             4         2020 Macbook Air                 M1
# ...             ...                      ...                ...
# HP              832                   255 G8  Ryzen 5 Hexa Core
# DELL            833            Inspiron 7430            Core i3
# MSI             834  Katana 17 B13UCXK-256IN            Core i7
# Infinix         835                     XL25            Core i5
# HP              836              13-BE0030AU  Ryzen 5 Hexa Core
#
#         Operating System Storage    RAM           Screen Size Touch_Screen  \
# Brand
# HP       Windows 11 Home  512 GB   8 GB  39.62 cm (15.6 Inch)           No
# HP       Windows 11 Home  512 GB   8 GB  39.62 cm (15.6 Inch)           No
# Apple     Mac OS Big Sur  256 GB   8 GB  33.78 cm (13.3 inch)           No
# Apple     Mac OS Big Sur  256 GB   8 GB  33.78 cm (13.3 inch)           No
# Apple     Mac OS Big Sur  256 GB   8 GB  33.78 cm (13.3 inch)           No
# ...                  ...     ...    ...                   ...          ...
# HP       Windows 11 Home  512 GB   8 GB  39.62 cm (15.6 inch)           No
# DELL     Windows 11 Home    1 TB   8 GB    35.56 cm (14 inch)          Yes
# MSI      Windows 11 Home    4 TB  16 GB  43.94 cm (17.3 Inch)           No
# Infinix  Windows 11 Home  512 GB   8 GB  39.62 cm (15.6 Inch)           No
# HP       Windows 10 Home  512 GB  16 GB  33.78 cm (13.3 inch)           No
#
#            Price
# Brand
# HP       ₹38,990
# HP       ₹37,990
# Apple    ₹70,990
# Apple    ₹70,990
# Apple    ₹70,990
# ...          ...
# HP       ₹42,990
# DELL     ₹60,490
# MSI      ₹88,990
# Infinix  ₹37,990
# HP       ₹70,500
#
# [837 rows x 9 columns]

# %%
laptop_data.loc["Apple"]
# Out:
#        Unnamed: 0        Model Name Processor Operating System Storage    RAM  \
# Brand
# Apple           2  2020 Macbook Air        M1   Mac OS Big Sur  256 GB   8 GB
# Apple           3  2020 Macbook Air        M1   Mac OS Big Sur  256 GB   8 GB
# Apple           4  2020 Macbook Air        M1   Mac OS Big Sur  256 GB   8 GB
# Apple          70       MacBook Pro        M2  Mac OS Monterey  256 GB   8 GB
# Apple         120       MacBook Air        M2  Mac OS Monterey  256 GB   8 GB
# Apple         301       MacBook Pro        M2  Mac OS Monterey  512 GB   8 GB
# Apple         567         MK1A3HN/A    M1 Max  Mac OS Monterey    1 TB  32 GB
# Apple         577         MPHG3HN/A    M2 Max    macOS Ventura    1 TB  32 GB
# Apple         688       MacBook Pro    M3 Pro     macOS Sonoma    1 TB  18 GB
# Apple         730         MKGT3HN/A    M1 Pro  Mac OS Monterey    1 TB  16 GB
# Apple         748       MacBook Pro   Core i5    Mac OS Mojave  512 GB   8 GB
#
#                 Screen Size Touch_Screen      Price
# Brand
# Apple  33.78 cm (13.3 inch)           No    ₹70,990
# Apple  33.78 cm (13.3 inch)           No    ₹70,990
# Apple  33.78 cm (13.3 inch)           No    ₹70,990
# Apple  33.78 cm (13.3 Inch)           No    ₹99,990
# Apple  34.54 cm (13.6 Inch)           No  ₹1,04,990
# Apple  33.78 cm (13.3 Inch)           No  ₹1,36,990
# Apple  41.15 cm (16.2 inch)           No  ₹3,09,490
# Apple    35.56 cm (14 Inch)           No  ₹2,90,990
# Apple    35.56 cm (14 Inch)           No  ₹2,39,900
# Apple  36.07 cm (14.2 inch)           No  ₹2,39,900
# Apple  33.78 cm (13.3 inch)           No  ₹1,62,990

# %%
laptop_data = laptop_data.reset_index()

# %%
laptop_data.loc[:, ["Brand", "Model Name", "Storage", "Price"]]
# Out:
#        Brand               Model Name Storage    Price
# 0         HP             15s-fq5007TU  512 GB  ₹38,990
# 1         HP             15s-fy5003TU  512 GB  ₹37,990
# 2      Apple         2020 Macbook Air  256 GB  ₹70,990
# 3      Apple         2020 Macbook Air  256 GB  ₹70,990
# 4      Apple         2020 Macbook Air  256 GB  ₹70,990
# ..       ...                      ...     ...      ...
# 832       HP                   255 G8  512 GB  ₹42,990
# 833     DELL            Inspiron 7430    1 TB  ₹60,490
# 834      MSI  Katana 17 B13UCXK-256IN    4 TB  ₹88,990
# 835  Infinix                     XL25  512 GB  ₹37,990
# 836       HP              13-BE0030AU  512 GB  ₹70,500
#
# [837 rows x 4 columns]

# %%
laptop_data.columns
# Out:
# Index(['Brand', 'Unnamed: 0', 'Model Name', 'Processor', 'Operating System',
#        'Storage', 'RAM', 'Screen Size', 'Touch_Screen', 'Price'],
#       dtype='object')

# %%
laptop_data.duplicated().sum()
# Out:
# 0
